# %%
# Necessary Installs

# %%
# Imports 
import os
import numpy as np
import json
import pickle
import random
import nltk
import tensorflow as tf
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('wordnet')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional,Embedding
from tensorflow.keras.optimizers import SGD
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/anirudh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/anirudh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
os.chdir('/home/anirudh/Documents/ML-ChatBot')

lemmatizer = WordNetLemmatizer()
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('data/intent1.json').read()
intents = json.loads(data_file)

for intent in intents['intents']:
    for pattern in intent['text']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent['intent']))
        if intent['intent'] not in classes:
            classes.append(intent['intent'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
names = ['Documents', 'Classes', 'Unique Words']
values = [len(documents), len(classes), len(words)]
plt.figure(figsize=(5, 5))
plt.bar(names, values)
plt.title('Data')
# Out:
# Text(0.5, 1.0, 'Data')

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training = []
output_empty = [0] * len(classes)
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# %%
random.shuffle(training)
training = np.array(training)
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-7-8e8c1affa596>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model/chatbot_model.h5', hist)
# Out:
# Epoch 1/200
# 29/29 [==============================] - 0s 1ms/step - loss: 3.0793 - accuracy: 0.0769
# Epoch 2/200
# 29/29 [==============================] - 0s 1ms/step - loss: 2.8017 - accuracy: 0.4196
# Epoch 3/200
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4991 - accuracy: 0.6084
# Epoch 4/200
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1466 - accuracy: 0.6993
# Epoch 5/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7987 - accuracy: 0.7483
# Epoch 6/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4949 - accuracy: 0.8392
# Epoch 7/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2476 - accuracy: 0.8741
# Epoch 8/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0545 - accuracy: 0.8811
# Epoch 9/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.8942 - accuracy: 0.8951
# Epoch 10/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.7630 - accuracy: 0.8811
# Epoch 11/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6673 - accuracy: 0.9231
# Epoch 12/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5758 - accuracy: 0.9231
# Epoch 13/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5165 - accuracy: 0.9371
# Epoch 14/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.9510
# Epoch 15/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4085 - accuracy: 0.9720
# Epoch 16/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3727 - accuracy: 0.9720
# Epoch 17/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3309 - accuracy: 0.9860
# Epoch 18/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3016 - accuracy: 0.9930
# Epoch 19/200
# 29/29 [==============================] - 0s 953us/step - loss: 0.2723 - accuracy: 1.0000
# Epoch 20/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2493 - accuracy: 1.0000
# Epoch 21/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2315 - accuracy: 1.0000
# Epoch 22/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2095 - accuracy: 1.0000
# Epoch 23/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 1.0000
# Epoch 24/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1765 - accuracy: 1.0000
# Epoch 25/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1632 - accuracy: 1.0000
# Epoch 26/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1515 - accuracy: 1.0000
# Epoch 27/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 1.0000
# Epoch 28/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1326 - accuracy: 1.0000
# Epoch 29/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1220 - accuracy: 1.0000
# Epoch 30/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 1.0000
# Epoch 31/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.1058 - accuracy: 1.0000
# Epoch 32/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0999 - accuracy: 1.0000
# Epoch 33/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0945 - accuracy: 1.0000
# Epoch 34/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 1.0000
# Epoch 35/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 36/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0792 - accuracy: 1.0000
# Epoch 37/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 1.0000
# Epoch 38/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0707 - accuracy: 1.0000
# Epoch 39/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0673 - accuracy: 1.0000
# Epoch 40/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 1.0000
# Epoch 41/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0614 - accuracy: 1.0000
# Epoch 42/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 43/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 44/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 45/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 46/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 47/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 48/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 49/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 50/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 51/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 52/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 53/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 54/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 55/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 56/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 57/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 58/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 59/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 60/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 61/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 62/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 63/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 64/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 65/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 66/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 67/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 68/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 69/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 70/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 71/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 72/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 73/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 74/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 75/200
# 29/29 [==============================] - 0s 942us/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 76/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 77/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 78/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 79/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 80/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 81/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 82/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 83/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 84/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 85/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 86/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 87/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 88/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 89/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 90/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 91/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 92/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 93/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 94/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 95/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 96/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 97/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 98/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 99/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 100/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 101/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 102/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 103/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 104/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 105/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 106/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 107/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 108/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 109/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 110/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 111/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 112/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 113/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 114/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 115/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 116/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 117/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 118/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 119/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 120/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 121/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 122/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 123/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 124/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 125/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 126/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 127/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 128/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 129/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 130/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 131/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 132/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 133/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 134/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 135/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 136/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 137/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 138/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 139/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 140/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 141/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 142/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 143/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 144/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 145/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 146/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 147/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 148/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 149/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 150/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 151/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 152/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 153/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 154/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 155/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 156/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 157/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 158/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 159/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 160/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 161/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 162/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 163/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 164/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 165/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 166/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 167/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 168/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 169/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 170/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 171/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 172/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 173/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 174/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 175/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 176/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 177/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 178/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 179/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 180/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 181/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 182/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 183/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 184/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 185/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 186/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 187/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 188/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 189/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 190/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 191/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 192/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 193/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 194/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 195/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 196/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 197/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 198/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 199/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 200/200
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000

# %%
from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.10
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    print(ints)
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['intent']== tag):
            return  random.choice(i['responses'])
            break
    return ''

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res
chatbot_response("Hey, how's your day been?")
# Out:
# [{'intent': 'NameQuery', 'probability': '0.7013623'}, {'intent': 'CourtesyGreeting', 'probability': '0.18910696'}]
# 'Call me Geni'
